# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %%
data = "C:/Users/CLINTON/Documents/My documents/LLM/Informatics/INFX 598/Group project/clean_data.csv"
df = pd.read_csv(data)

# %%
df.head()
# Out:
#    energy_star_rating  january_min_temp  january_avg_temp  february_min_temp  \
# 0           61.048605                15         38.274194                 19
# 1           61.048605                21         47.693548                 27
# 2           61.048605                21         47.693548                 27
# 3           61.048605                21         47.693548                 27
# 4           61.048605                21         47.693548                 27
#
#    february_avg_temp  february_max_temp  march_min_temp  march_avg_temp  \
# 0          35.785714                 60              14       38.000000
# 1          51.120690                 80              31       50.758065
# 2          51.120690                 80              31       50.758065
# 3          51.120690                 80              31       50.758065
# 4          51.120690                 80              31       50.758065
#
#    april_min_temp  april_avg_temp  ...  heating_degree_days  \
# ...

# %%
df[::-1] #reverse df
# Out:
#        energy_star_rating  january_min_temp  january_avg_temp  \
# 68393           98.000000                28         43.451613
# 68392            8.000000                28         43.451613
# 68391           79.000000                28         43.451613
# 68390           61.048605                28         43.451613
# 68389           61.048605                28         43.451613
# ...                   ...               ...               ...
# 4               61.048605                21         47.693548
# 3               61.048605                21         47.693548
# 2               61.048605                21         47.693548
# 1               61.048605                21         47.693548
# 0               61.048605                15         38.274194
#
#        february_min_temp  february_avg_temp  february_max_temp  \
# 68393                 34          47.672414                 64
# 68392                 34          47.672414                 64
# ...

# %%
df[::100]
# Out:
#        energy_star_rating  january_min_temp  january_avg_temp  \
# 0               61.048605                15         38.274194
# 100             61.048605                15         37.500000
# 200             80.000000                15         37.500000
# 300             88.000000                15         37.500000
# 400             61.048605                15         37.500000
# ...                   ...               ...               ...
# 67900           71.000000                28         43.451613
# 68000           75.000000                28         43.451613
# 68100           11.000000                28         43.451613
# 68200           71.000000                28         43.451613
# 68300           61.048605                28         43.451613
#
#        february_min_temp  february_avg_temp  february_max_temp  \
# 0                     19          35.785714                 60
# 100                   17          35.732143                 58
# ...

# %%
df.head()
# Out:
#    energy_star_rating  january_min_temp  january_avg_temp  february_min_temp  \
# 0           61.048605                15         38.274194                 19
# 1           61.048605                21         47.693548                 27
# 2           61.048605                21         47.693548                 27
# 3           61.048605                21         47.693548                 27
# 4           61.048605                21         47.693548                 27
#
#    february_avg_temp  february_max_temp  march_min_temp  march_avg_temp  \
# 0          35.785714                 60              14       38.000000
# 1          51.120690                 80              31       50.758065
# 2          51.120690                 80              31       50.758065
# 3          51.120690                 80              31       50.758065
# 4          51.120690                 80              31       50.758065
#
#    april_min_temp  april_avg_temp  ...  heating_degree_days  \
# ...

# %%
rslt_df = df.loc[df['energy_star_rating'] < 61]
rslt_df[['january_min_temp','february_min_temp','february_max_temp']]
# Out:
#        january_min_temp  february_min_temp  february_max_temp
# 44                   11                 16                 73
# 51                   11                 16                 73
# 64                   14                 21                 70
# 65                   14                 21                 70
# 74                   15                 17                 58
# ...                 ...                ...                ...
# 68357                28                 34                 64
# 68361                28                 34                 64
# 68363                28                 34                 64
# 68387                28                 34                 64
# 68392                28                 34                 64
#
# [19637 rows x 3 columns]

# %%
df.describe()
# Out:
#        energy_star_rating  january_min_temp  january_avg_temp  \
# count        68394.000000      68394.000000      68394.000000
# mean            60.391665          9.888923         33.077615
# std             23.153519          7.486553          5.337691
# min              1.000000        -19.000000         10.806452
# 25%             55.000000          4.000000         29.827586
# 50%             61.048605         11.000000         34.451613
# 75%             75.000000         11.000000         35.080645
# max            100.000000         35.000000         53.032258
#
#        february_min_temp  february_avg_temp  february_max_temp  \
# count       68394.000000       68394.000000       68394.000000
# mean            9.660804          34.028844          57.014957
# std            10.962963           7.535903           7.370250
# min           -13.000000          13.250000          38.000000
# 25%             2.000000          31.625000          55.000000
# ...

# %%
final_df = rslt_df.sort_values(by=['energy_star_rating'], ascending=False)

# %%
final_df
# Out:
#        energy_star_rating  january_min_temp  january_avg_temp  \
# 40862                60.0                 8         29.854839
# 58749                60.0                 4         32.903226
# 22480                60.0                11         35.080645
# 31844                60.0                 4         28.596774
# 17500                60.0                13         37.322581
# ...                   ...               ...               ...
# 51258                 1.0                11         34.451613
# 63167                 1.0                28         45.419355
# 63166                 1.0                28         45.419355
# 63161                 1.0                28         45.419355
# 36539                 1.0                 8         29.854839
#
#        february_min_temp  february_avg_temp  february_max_temp  \
# 40862                  2          23.946429                 43
# 58749                 12          32.160714                 56
# ...

# %%
final_df.iat[4,3]
# Out:
# 20

# %%
#.at look at labels
final_df.at[17500,'january_avg_temp']
# Out:
# 37.32258065
