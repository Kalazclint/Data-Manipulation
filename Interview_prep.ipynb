# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
plt.style.use("seaborn-darkgrid")

# %%
data = 'C:/Users/CLINTON/OneDrive/Documents/Excel Data Analysis/ChicagoCrimeData.csv'
chicagoCrimeData = pd.read_csv(data)
chicagoCrimeData.head()
# Out:
#          ID CASE_NUMBER        DATE                     BLOCK IUCR  \
# 0   3512276    HK587712  2004-08-28        047XX S KEDZIE AVE  890
# 1   3406613    HK456306  2004-06-26  009XX N CENTRAL PARK AVE  820
# 2   8002131    HT233595  2011-04-04        043XX S WABASH AVE  820
# 3   7903289    HT133522  2010-12-30      083XX S KINGSTON AVE  840
# 4  10402076    HZ138551  2016-02-02           033XX W 66TH ST  820
#
#   PRIMARY_TYPE                    DESCRIPTION          LOCATION_DESCRIPTION  \
# 0        THEFT                  FROM BUILDING            SMALL RETAIL STORE
# 1        THEFT                 $500 AND UNDER                         OTHER
# 2        THEFT                 $500 AND UNDER  NURSING HOME/RETIREMENT HOME
# 3        THEFT  FINANCIAL ID THEFT: OVER $300                     RESIDENCE
# 4        THEFT                 $500 AND UNDER                         ALLEY
#
#    ARREST  DOMESTIC  ...  DISTRICT  WARD  COMMUNITY_AREA_NUMBER  FBICODE  \
# ...

# %%
file = 'C:/Users/CLINTON/OneDrive/Documents/Excel Data Analysis/ChicagoCensusData.csv'
chicagoCensusData = pd.read_csv(file)
chicagoCensusData.head()
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 0                    1.0         Rogers Park                         7.7
# 1                    2.0          West Ridge                         7.8
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 0                              23.6                          8.7
# 1                              17.2                          8.8
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 0                                          18.2
# ...

# %%
chicagoCensusData.iat[4,3]
# Out:
# 7.5

# %%
df[::-1] #reverse df

# %%
#sorting by hardship index
Hardship_index_sorting = chicagoCensusData.head().sort_values(by=['HARDSHIP_INDEX'], ascending=False)
Hardship_index_sorting
# Out:
#    COMMUNITY_AREA_NUMBER COMMUNITY_AREA_NAME  PERCENT_OF_HOUSING_CROWDED  \
# 1                    2.0          West Ridge                         7.8
# 0                    1.0         Rogers Park                         7.7
# 2                    3.0              Uptown                         3.8
# 3                    4.0      Lincoln Square                         3.4
# 4                    5.0        North Center                         0.3
#
#    PERCENT_HOUSEHOLDS_BELOW_POVERTY  PERCENT_AGED_16__UNEMPLOYED  \
# 1                              17.2                          8.8
# 0                              23.6                          8.7
# 2                              24.0                          8.9
# 3                              10.9                          8.2
# 4                               7.5                          5.2
#
#    PERCENT_AGED_25__WITHOUT_HIGH_SCHOOL_DIPLOMA  \
# 1                                          20.8
# ...

# %%
csv = 'C:/Users/CLINTON/OneDrive/Documents/Excel Data Analysis/ChicagoPublicSchools.csv'
chicagoPublicSchools = pd.read_csv(csv)
chicagoPublicSchools.head()
# Out:
#    School_ID                                     NAME_OF_SCHOOL  \
# 0     610038                  Abraham Lincoln Elementary School
# 1     610281  Adam Clayton Powell Paideia Community Academy ...
# 2     610185                Adlai E Stevenson Elementary School
# 3     609993                    Agustin Lara Elementary Academy
# 4     610513                      Air Force Academy High School
#
#   Type_of_School         Street_Address     City State  ZIP_Code  \
# 0             ES        615 W Kemper Pl  Chicago    IL     60614
# 1             ES  7511 S South Shore Dr  Chicago    IL     60649
# 2             ES     8010 S Kostner Ave  Chicago    IL     60652
# 3             ES     4619 S Wolcott Ave  Chicago    IL     60609
# 4             HS        3630 S Wells St  Chicago    IL     60609
#
#      Phone_Number                                               Link  \
# 0  (773) 534-5720  http://schoolreports.cps.edu/SchoolProgressRep...
# ...

# %%
chicagoPublicSchools[['NAME_OF_SCHOOL','COMMUNITY_AREA_NAME']].duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 561    False
# 562    False
# 563    False
# 564    False
# 565    False
# Length: 566, dtype: bool

# %%
#List community areas with per capita income less than 11000
poor_countries = chicagoCensusData.loc[chicagoCensusData['PER_CAPITA_INCOME'] < 11000]
poor_countries = poor_countries[['COMMUNITY_AREA_NAME','PER_CAPITA_INCOME']]
poor_countries
# Out:
#    COMMUNITY_AREA_NAME  PER_CAPITA_INCOME
# 25  West Garfield Park              10934
# 29      South Lawndale              10402
# 36         Fuller Park              10432
# 53           Riverdale               8201

# %%
plt.figure(figsize=(8,4))
sns.barplot(x = poor_countries['COMMUNITY_AREA_NAME'], y = poor_countries['PER_CAPITA_INCOME'])

plt.xlabel('Community_area_name')
plt.ylabel("Per_Capita_Income")
plt.title("Per_Capita_Income for Community Area")
# Out:
# Text(0.5, 1.0, 'Per_Capita_Income for Community Area')

# %%
chicagoCrimeData['DESCRIPTION'].value_counts()
# Out:
# SIMPLE                                         59
# $500 AND UNDER                                 48
# DOMESTIC BATTERY SIMPLE                        37
# TO PROPERTY                                    28
# OVER $500                                      26
#                                                ..
# ILLEGAL USE CASH CARD                           1
# AGG RIT MUT: HANDS/FIST/FEET SERIOUS INJURY     1
# INTIMIDATION                                    1
# FINANCIAL ID THEFT: OVER $300                   1
# ILLEGAL CONSUMPTION BY MINOR                    1
# Name: DESCRIPTION, Length: 103, dtype: int64

# %%
chicagoPublicSchools.columns
# Out:
# Index(['School_ID', 'NAME_OF_SCHOOL', 'Type_of_School', 'Street_Address',
#        'City', 'State', 'ZIP_Code', 'Phone_Number', 'Link', 'Network_Manager',
#        'Collaborative_Name', 'Adequate_Yearly_Progress_Made_',
#        'Track_Schedule', 'CPS_Performance_Policy_Status',
#        'CPS_Performance_Policy_Level', 'HEALTHY_SCHOOL_CERTIFIED',
#        'Safety_Icon', 'SAFETY_SCORE', 'Family_Involvement_Icon',
#        'Family_Involvement_Score', 'Environment_Icon', 'Environment_Score',
#        'Instruction_Icon', 'Instruction_Score', 'Leaders_Icon',
#        'Leaders_Score', 'Teachers_Icon', 'Teachers_Score',
#        'Parent_Engagement_Icon', 'Parent_Engagement_Score',
#        'Parent_Environment_Icon', 'Parent_Environment_Score',
#        'AVERAGE_STUDENT_ATTENDANCE', 'Rate_of_Misconducts__per_100_students_',
#        'Average_Teacher_Attendance',
#        'Individualized_Education_Program_Compliance_Rate', 'Pk_2_Literacy__',
# ...

# %%
#List the average safety score for all types of schools.
average_safety_scores = chicagoPublicSchools.groupby(['Type_of_School'])['SAFETY_SCORE'].mean().reset_index().sort_values(by="SAFETY_SCORE",ascending=False)
average_safety_scores
# Out:
#   Type_of_School  SAFETY_SCORE
# 1             HS     49.623529
# 0             ES     49.520384
# 2             MS     48.000000

# %%
#5 community areas with highest % of households below poverty line
poor_communities = chicagoCensusData.groupby(['COMMUNITY_AREA_NAME'])['PERCENT_HOUSEHOLDS_BELOW_POVERTY'].sum().reset_index().sort_values(by="PERCENT_HOUSEHOLDS_BELOW_POVERTY",ascending=False)

# %%
poor_communities.head(5)
# Out:
#    COMMUNITY_AREA_NAME  PERCENT_HOUSEHOLDS_BELOW_POVERTY
# 60           Riverdale                              56.5
# 26         Fuller Park                              51.2
# 24           Englewood                              46.6
# 53      North Lawndale                              43.1
# 20  East Garfield Park                              42.4

# %%
#Which community area is most crime prone?
crime_prone_community = chicagoCrimeData.groupby(['COMMUNITY_AREA_NUMBER'])['CASE_NUMBER'].count().reset_index().sort_values(by="CASE_NUMBER",ascending=False)

# %%
crime_prone_community.head(1)
# Out:
#     COMMUNITY_AREA_NUMBER  CASE_NUMBER
# 22                   25.0           43

# %%
Most_crime_prone = chicagoCensusData.loc[chicagoCensusData['COMMUNITY_AREA_NUMBER'] == 25.0]
Most_crime_prone[['COMMUNITY_AREA_NAME','COMMUNITY_AREA_NUMBER']]
# Out:
#    COMMUNITY_AREA_NAME  COMMUNITY_AREA_NUMBER
# 24              Austin                   25.0

# %%
#the name of the community area with highest hardship index
hardship_index = chicagoCensusData.groupby(['COMMUNITY_AREA_NAME'])['HARDSHIP_INDEX'].sum().reset_index().sort_values(by="HARDSHIP_INDEX",ascending=False)
hardship_index.head(1)
# Out:
#    COMMUNITY_AREA_NAME  HARDSHIP_INDEX
# 60           Riverdale            98.0

# %%
#Merging to dataframe with common columns

#merged_inner = pd.merge(left=survey_sub, right=species_sub, left_on='species_id', right_on='species_id', how='inner')

# %%
#Pivot Table

#df = df.pivot_table(index='date', columns='paying_customer', values='downloads', aggfunc='sum')
#df[df['no']>df['yes']].reset_index()

# %%
#result=df.merge(df1,left_on='user_id',right_on='id',how='inner')

# %% [markdown]
# Find the customer with the highest daily total order cost between 2019-02-01 to 2019-05-01. If customer had more than one order on a certain day, sum the order costs on daily basis. Output customer's first name, total cost of their items, and the date.

# %%
# Import your libraries
import pandas as pd

# Start writing code
df = pd.merge(left=customers, right=orders, left_on='id', right_on='cust_id', how='inner')
df= df.groupby(['first_name','order_date'])['total_order_cost'].sum().reset_index().sort_values(by= 'total_order_cost', ascending=False)
df['order_date'] = df['order_date'].dt.strftime('%Y-%m-%d')
df = df[df['order_date'].between("2019-02-01","2019-05-01")]
df = df.head(1)
df

# %% [markdown]
# Find the correlation between the annual salary and the length of the service period of a Lyft driver.

# %%
# Import your libraries
import pandas as pd

# Start writing code
lyft_drivers
lyft_drivers['start_date'] = pd.to_datetime(lyft_drivers['start_date'], format='%Y-%m-%d')
lyft_drivers['end_date'] = pd.to_datetime(lyft_drivers['end_date'], format='%Y-%m-%d')
lyft_drivers['end_date'] =lyft_drivers['end_date'].fillna(pd.datetime.today())
lyft_drivers['service_length'] = (lyft_drivers['end_date'] -lyft_drivers['start_date']).dt.day
correlation = lyft_drivers['service_length'].corr(lyft_drivers['yearly_salary']) 

df['yyyy-mm'] = pd.to_datetime(df['ArrivalDate']).dt.strftime('%Y-%m')

monthly_revenue['prev_month'] = monthly_revenue.value.shift(1)

# %% [markdown]
# .transform('mean') apply transform to all columns

# %% [markdown]
# Find matching hosts and guests in a way that they are both of the same gender and nationality

# %%
# Import your libraries
import pandas as pd

# Start writing code
airbnb_hosts.head()
air_bnb = airbnb_hosts.merge(airbnb_guests, on=['nationality', 'gender'])
air_bnb[['host_id','guest_id']].drop_duplicates()

# %% [markdown]
# searching for words in a column
#
# hotel_reviews[(hotel_reviews.hotel_address.str.contains('Netherlands$'))
